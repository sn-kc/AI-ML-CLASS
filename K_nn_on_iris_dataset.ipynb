# %% [markdown]
# <a href="https://colab.research.google.com/github/sn-kc/AI-ML-CLASS/blob/main/K_nn_on_iris_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Loading necessary libraries and data

# %%
from sklearn.datasets import load_iris
# loading k-nn classifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Load the Iris dataset
iris = load_iris()

# %% [markdown]
# # Data splitting into Training and testing  sets

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2, random_state=42)

# %% [markdown]
# # Training the model (KNN)

# %%
# Create a k-NN classifier object with k=3
knn = KNeighborsClassifier(n_neighbors=3)

# Fit the classifier to the training data
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# # Calculating accuracy of model on test data

# %%
# Predict the target values for the testing data
y_pred = knn.predict(X_test)

# Calculate the accuracy score of the classifier
accuracy = accuracy_score(y_test, y_pred)

print('Accuracy: %.3f' % accuracy)
# Out:
# Accuracy: 1.000

# %% [markdown]
# # Calculating accuracy of model on training data

# %%
# Predict the target values for the training data
y_pred = knn.predict(X_train)

# Calculate the accuracy score of the classifier
accuracy = accuracy_score(y_train, y_pred)

print('Accuracy: %.3f' % accuracy)
# Out:
# Accuracy: 0.950

# %% [markdown]
# # Finding confusion matrix

# %%
from sklearn.metrics import confusion_matrix
y_pred = knn.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]

# %% [markdown]
# # Plotting confusion matrix

# %%
# Plot confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt

# confusion matrix sns heatmap
ax = plt.axes()
df_cm = cm
sns.heatmap(df_cm, annot=True, annot_kws={"size": 30}, fmt='d',cmap="Blues", ax = ax )
ax.set_title('Confusion Matrix')
plt.show()

# %% [markdown]
# # Finding Accuracy,Precision and Recall on test data

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred,average=None))
print("Recall:",metrics.recall_score(y_test, y_pred,average=None))
# Out:
# Accuracy: 1.0
# Precision: [1. 1. 1.]
# Recall: [1. 1. 1.]

# %% [markdown]
# # Finding f1 score on test data

# %%
from sklearn.metrics import f1_score
print("f1 score for base model is : " , f1_score(y_test,y_pred,average='micro'))
# Out:
# f1 score for base model is :  1.0

# %% [markdown]
# This code will perform k-NN classification on the Iris dataset with k=3, split the data into training and testing sets, fit the classifier to the training data, and predict the target values for the testing data. Finally, it will calculate and print the accuracy score of the classifier.

# %% [markdown]
# #identifying best no of neighbors using Grid search C V

# %%
from sklearn.model_selection import GridSearchCV
parameters = {"n_neighbors": range(1, 50)}
gridsearch = GridSearchCV(KNeighborsClassifier(), parameters)
gridsearch.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': range(1, 50)})

# %%
gridsearch.best_params_   #identifying best no of neighbors
# Out:
# {'n_neighbors': 3}
